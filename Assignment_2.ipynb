# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiManjithMatta/Assignment-2/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Numpy:**
#
# Using NumPy create random vector of size 15 having only Integers in the range 1-20.
#
# 1.1. Reshape the array to 3 by 5
#
# 1.2. Print array shape.
#
# 1.3. Replace the max in each row by 0

# %%
import numpy
#1.1 creating a random vector of range 1-20 and size = 15

ran_vec = numpy.random.randint(1, 20, size = 15).reshape(3,5)
print(ran_vec)
# Out:
# [[17 15  1  8 16]
#  [12  1 18 19  4]
#  [17  2 11  2 19]]

# %%
#1.2 Priniting th e array size
print("Array-Shape: ", ran_vec.shape)
# Out:
# Array-Shape:  (3, 5)

# %%
#1.3 Repalcing the max 
Max_val = numpy.amax(ran_vec, axis = 1)

Max_val = Max_val[: , None]

Updated_Arr = numpy.where(ran_vec == Max_val, 0, ran_vec)

print(Updated_Arr)
# Out:
# [[ 0 15  1  8 16]
#  [12  1 18  0  4]
#  [17  2 11  2  0]]

# %% [markdown]
# **2. Pandas**
#
# 1. Read the provided CSV file ‘data.csv’.
# https://drive.google.com/drive/folders/1h8C3mLsso-R-sIOLsvoYwPLzy2fJ4IOF?usp=sharing
# 2. Show the basic statistical description about the data.
# 3. Check if the data has null values.
# a. Replace the null values with the mean
# 4. Select at least two columns and aggregate the data using: min, max, count, mean.
# 5. Filter the dataframe to select the rows with calories values between 500 and 1000.
# 6. Filter the dataframe to select the rows with calories values > 500 and pulse < 100.
# 7. Create a new “df_modified” dataframe that contains all the columns from df except for “Maxpulse”.
# 8. Delete the “Maxpulse” column from the main df dataframe
# 9. Convert the datatype of Calories column to int datatype.
# 10. Using pandas create a scatter plot for the two columns (Duration and Calories)

# %%
#2.1 Reading the data
import pandas
from google.colab import drive
drive.mount('/content/gdrive')
file = pandas.read_csv("gdrive/My Drive/data.csv")
file.head(10)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
#2.2 basic statistical description
file.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
'''2.3 Check if the data has null values.
          a. Replace the null values with the mean'''
#checking the Null values
file.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
'''mean_Duration = file['Duration'].mean()
mean_Pulse = file['Pulse'].mean()
mean_MaxPulse = file['Maxpulse'].mean()'''
mean_Calories = file['Calories'].mean()
print("Mean :",mean_Calories)
file['Calories'].fillna(value=mean_Calories,inplace=True)
file.head(20)
# Out:
# Mean : 375.79024390243904
#     Duration  Pulse  Maxpulse    Calories
# 0         60    110       130  409.100000
# 1         60    117       145  479.000000
# 2         60    103       135  340.000000
# 3         45    109       175  282.400000
# 4         45    117       148  406.000000
# 5         60    102       127  300.000000
# 6         60    110       136  374.000000
# 7         45    104       134  253.300000
# 8         30    109       133  195.100000
# 9         60     98       124  269.000000
# 10        60    103       147  329.300000
# 11        60    100       120  250.700000
# 12        60    106       128  345.300000
# 13        60    104       132  379.300000
# 14        60     98       123  275.000000
# 15        60     98       120  215.200000
# 16        60    100       120  300.000000
# 17        45     90       112  375.790244
# 18        60    103       123  323.000000
# 19        45     97       125  243.000000

# %%
#2.4 Select at least two columns and aggregate the data using: min, max, count, mean.
file[['Duration','Pulse']].describe()
# Out:
#          Duration       Pulse
# count  169.000000  169.000000
# mean    63.846154  107.461538
# std     42.299949   14.510259
# min     15.000000   80.000000
# 25%     45.000000  100.000000
# 50%     60.000000  105.000000
# 75%     60.000000  111.000000
# max    300.000000  159.000000

# %%
# 2.5 Filter the dataframe to select the rows with calories values between 500 and 1000
file[(file['Calories']>500) & (file['Calories']<1000)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
#2.6 Filter the dataframe to select the rows with calories values > 500 and pulse < 100.

file[(file['Calories']>500) & (file['Pulse']<1000)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 60        210    108       160    1376.0
# 61        160    110       137    1034.4
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 69        300    108       143    1500.2
# 70        150     97       129    1115.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 79        270    100       131    1729.0
# 87        120    100       157    1000.1
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3
# 109       210    137       184    1860.4

# %%
#2.7 Create a new “df_modified” dataframe that contains all the columns from df except for “Maxpulse”.
df_modified = file.drop("Maxpulse",axis=1) 
print(df_modified)
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
#2.8 Delete the “Maxpulse” column from the main df dataframe
file=file.drop("Maxpulse",axis=1)
file
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
#2.9 Convert the datatype of Calories column to int datatype.
file['Calories']=file['Calories'].astype(int)
file.dtypes
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object

# %%
#2.10 Using pandas create a scatter plot for the two columns (Duration and Calories).

file.plot.scatter( x = 'Duration', y = 'Calories')

# %% [markdown]
# **3. Matplotlib**
#
# 1. Write a Python programming to create a below chart of the popularity of programming Languages.
# 2. Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
# %matplotlib inline

from matplotlib import pyplot as plot


lang = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['#1f77b4','#ff7f0e','#2ca02c','#d62728','#9467bd','#8c564b']

explode = [0.1,0,0,0,0,0]


plot.pie(popularity,labels=lang,colors=colors,explode=explode,startangle=130,
       wedgeprops = {'edgecolor':'black'},autopct='%1.1f%%')



plot.tight_layout()
plot.show()
